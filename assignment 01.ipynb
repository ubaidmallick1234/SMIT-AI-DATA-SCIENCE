# %% [markdown]
# # 1 Variables + Print()

# %%
Store_name = input("Enter a store name:")
age_ = input("Enter a age:")
cource_ = input("Enter a cource:")
institute_ = input("Enter a institute:")

print(f"""
Store name: {Store_name}
age: {age_}
cource: {cource_}
institute: {institute_}
""")
# Out:
# Enter a store name: Ali General Store
# Enter a age: 20
# Enter a cource: AI And DS
# Enter a institute: Hajiyani Sakeena Campus (Saylani Mass IT)
# Store name: Ali General Store
# age: 20
# cource: AI And DS
# institute: Hajiyani Sakeena Campus (Saylani Mass IT)

# %%
Store_employee_name = input("Enter a store employee name:")
department_ = input("Enter a department:")
salary_ = input("Enter a salary:")
experience_ = input("Enter a experience:")

print(f"""
Store employee name: {Store_employee_name}
department: {department_}
salary: {salary_}
experience: {experience_}
""")
# Out:
# Enter a store employee name: Zameer Hussain
# Enter a department: Fazal Industries
# Enter a salary: 34000
# Enter a experience: 4 years
# Store employee name: Zameer Hussain
# department: Fazal Industries
# salary: 34000
# experience: 4 years

# %%
Store_product_name = input("Enter a store product name:")
price_ = input("Enter a price:")
quntity_ = input("Enter a quntity:")

print(f"""
Store product name: {Store_product_name}
price: {price_}
quntity: {quntity_}
""")
# Out:
# Enter a store product name: Azan Milk Shop
# Enter a price: 230
# Enter a quntity: 1 Liter
# Store product name: Azan Milk Shop
# price: 230
# quntity: 1 Liter

# %% [markdown]
# # (2) Input () Function

# %%
user_name = input("Enter a user name:")
age_ = input("Enter a age:")
city_ = input("Enter a city:")
cource_ = input("Enter a cource:")

print(f"""
user name: {user_name}
age: {age_}
city: {city_}
cource: {cource_}
""")
# Out:
# Enter a user name: Ubaid Iftikhar Malick
# Enter a age: 28
# Enter a city: karachi
# Enter a cource: AI And DS
# user name: Ubaid Iftikhar Malick
# age: 28
# city: karachi
# cource: AI And DS

# %%
user_name = input("Enter your name: ")
print(f"Welcome, {user_name}")
# Out:
# Enter your name:  akrama
# Welcome, akrama

# %%
name_ = input("Enter a name:")
roll_number_ = input("Enter a roll number:")
cource_ = input("Enter a cource:")
semester_ = input("Enter a semester:")

print(f"""
name: {name_}
roll number: {roll_number_}
cource: {cource_}
semester: {semester_}
""")
# Out:
# Enter a name: Zameer
# Enter a roll number: 65437
# Enter a cource: AI and ds
# Enter a semester: 1st
# name: Zameer
# roll number: 65437
# cource: AI and ds
# semester: 1st

# %% [markdown]
# # (3) int(),float(),str()

# %%
birth_year = 1998
birth_year = int(input("Enter birth year: "))
age = 2026 - birth_year
print(age)
# Out:
# Enter birth year:  1998
# 28

# %%
product_price = 50.75
quantity_ = 10
price = float(input("Enter product price:"))
quantity = int(input("Enter quantity:"))

total = price * quantity

print("Total bill:", total)
# Out:
# Enter product price: 50.75
# Enter quantity: 10
# Total bill: 507.5

# %%
celsius_ = 16
fahrenheit_ = (celsius_ * 9/5) + 32
celsius = float(input("Enter temperature in Celsius:"))
fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 16
# Temperature in Fahrenheit: 60.8

# %%
chemistry_ = 54
physics_ = 60
biology_ = 70


chemistry = float(input("Chemistry: "))
physics = float(input("Physics: "))
biology = float(input("Biology: "))

total = chemistry + physics + biology
average = total/3

print("Total marks:", total)
print("Average marks:", average)
# Out:
# Chemistry:  54
# Physics:  60
# Biology:  70
# Total marks: 184.0
# Average marks: 61.333333333333336

# %% [markdown]
# # (4) String Concatenation

# %%
"Zameer" + "Hussain"
print("Zameer + Hussain")
# Out:
# Zameer + Hussain

# %%
"Zameer" + "Hussain" +"zameersheikh221199@gmail.com"
print("Zameer + Hussain + zameersheikh221199@gmail.com")
# Out:
# Zameer + Hussain + zameersheikh221199@gmail.com

# %%
print("house number : 340 sector 15/A orangi town karachi")
print("street : 2nd")
print("city : karachi")
# Out:
# house number : 340 sector 15/A orangi town karachi
# street : 2nd
# city : karachi

# %% [markdown]
# # (5) String Repetition

# %%
"Zameer hussain" * 5
# Out:
# 'Zameer hussainZameer hussainZameer hussainZameer hussainZameer hussain'

# %% [markdown]
# # (6) Arithmetic Operators

# %%
number_1 = 20
number_2 = 40
number1 = float(input("Enter first number: "))
number2 = float(input("Enter second number: "))

print("Addition:", number1 + number2)
print("Subtraction:", number1 - number2)
print("Multiplication:", number1 * number2)
print("Division:", number1 / number2)
print("Modulus:", number1 % number2)
# Out:
# Enter first number:  20
# Enter second number:  40
# Addition: 60.0
# Subtraction: -20.0
# Multiplication: 800.0
# Division: 0.5
# Modulus: 20.0

# %%
length = float(input("Enter length:"))
width = float(input("Enter width:"))

area = length * width
perimeter = 2 * (length + width)

print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Enter length: 50
# Enter width: 70
# Area: 3500.0
# Perimeter: 240.0

# %%
length = float(input("Enter length:"))
width = float(input("Enter width:"))

area = length * width
perimeter = 2 * (length + width)

print("Area:", area)
print("Perimeter:", perimeter)

# %% [markdown]
# # (7) Comparsion Operator

# %%
age = int(input("Enter age:"))

print("20 >= older:", age >= 18)
# Out:
# Enter age: 20
# 20 >= older: True

# %%
marks = float(input("Enter marks:"))

print("65.5 <= :", marks >= 50)
# Out:
# Enter marks: 65.5
# 65.5 <= : True

# %% [markdown]
# # (8) Logical Operator

# %%
age = int(input("Enter age: "))

print(age > 18)
# Out:
# Enter age:  20
# True

# %%
marks = float(input("Enter marks: "))
age = int(input("Enter age: "))

print(marks >= 50 and age >= 18)
# Out:
# Enter marks:  65.5
# Enter age:  21
# True

# %%
amount = float(input("Enter purchase amount: "))
member = input("Are you a member? ")

print(amount >= 5000 or member == "yes")
# Out:
# Enter purchase amount:  5000
# Are you a member?  yes
# True

# %%
username = input("Enter username: ")
password = input("Enter password: ")

print(username == "zameer" and password == "1234")
# Out:
# Enter username:  zameer
# Enter password:  1234
# True

# %% [markdown]
# # (9) Membership OPerators-in/not in

# %%
"character" in "character"
# Out:
# True

# %%
"yasirarafat2233@gmail.com" in "@"
# Out:
# False

# %%
sentence = input("Enter a sentence: ")

print("Python" in sentence)
# Out:
# Enter a sentence:  i am learning Python
# True

# %%
radius = float(input("Enter radius: "))

pi = 3.14159
area = pi * radius * radius
circumference = 2 * pi * radius

print("Area:", area)
print("Circumference:", circumference)

# %%
radius = float(input("Enter radius: "))

pi = 3.14159
area = pi * radius * radius
circumference = 2 * pi * radius

print("Area:", area)
print("Circumference:", circumference)

# %%
price = int(input("Enter price: "))
quantity = int(input("Enter quantity: "))
discount_percent = int(input("Enter discount percentage: "))

subtotal = price * quantity
discount = subtotal * discount_percent / 100
final_price = subtotal - discount

print("Subtotal:", subtotal)
print("Discount:", discount)
print("Final Price:", final_price
